# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %tensorflow_version 1.x
# !pip install keras==2.3.1

# %%
# My drive一定要改名, 不然很麻煩
# !ln -s /content/drive/My\ Drive/ mydrive

# %%
# 直接把這包Code放在雲端硬碟上就好
#!git clone https://github.com/qqwweee/keras-yolo3.git

# %%
# 重新編譯預訓練文件
# !python3 mydrive/kerasYoloV4/code/convert.py mydrive/kerasYoloV4/code/yolov4.cfg mydrive/kerasYoloV4/yolov4.weights  mydrive/kerasYoloV4/code/model_data/yolo.h5

# %%
# 先測試一下官方訓練好的YOLO
# !python3 mydrive/kerasYoloV4/code/test.py

# %%
# 將訓練文件解壓縮
import zipfile
zfile = zipfile.ZipFile("/content/mydrive/專題/tibame04_v6.zip")
zfile.extractall("tibame04_v6")

# %%
# 產生訓練用的txt檔
# !python3 mydrive/kerasYoloV4/code/tibame_annotation.py

# %%
# 測試用, 產生訓練用txt並挑選類別和數量
#!python3 mydrive/kerasYoloV3/code/voc_annotation_select.py

# %%
# 訓練
# !python3 mydrive/kerasYoloV4/code/train.py -gpu_num 4
